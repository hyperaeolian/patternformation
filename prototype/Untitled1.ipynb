# %%
def mandelbrot(height,width,max_iters=20):
    y,x = ogrid[-1.4:1.4:height*1j, -2:0.8:width*1j]
    c = x + y * 1j
    z = c
    divTime = max_iters + zeros(z.shape, dtype=int)
    for i in xrange(max_iters):
        z = z**2 + c
        diverge = z*conj(z) > 4
        div_now = diverge & (divTime==max_iters)
        divTime[div_now] = i
        z[diverge] = 2
    return divTime

# %%
imshow(mandelbrot(600,700,100))

# %%
from essentia.standard import *

# %%
loader = MonoLoader(filename='/Users/milrob/Desktop/waterGames.wav')
audio = loader()

# %%
w = Windowing(type='hann')
fft = FFT()
mfcc = MFCC()

# %%
analyzed = []
for f in FrameGenerator(audio, frameSize=1024, hopSize=512):
    analyzed.append(fft(w(f)))

# %%
def mandelbrot(height,width,sound,max_iters=20):
    y = [s.real for s in sound[0]]
    x = [s.imag for s in sound[0]]
    c = x + y
    z = c
    divTime = max_iters + zeros(2, dtype=int)
    for i in xrange(max_iters):
        z = z**2 + c
        diverge = z*conj(z) > 4
        div_now = diverge & (divTime==max_iters)
        divTime[div_now] = i
        z[diverge] = 2
    return divTime

# %%
imshow(mandelbrot(400,400,analyzed))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-7d051bbfb0d8> in <module>()
# ----> 1 imshow(mandelbrot(400,400,analyzed))
#
# <ipython-input-33-5e6201c04c53> in mandelbrot(height, width, sound, max_iters)
#       6     divTime = max_iters + zeros(2, dtype=int)
#       7     for i in xrange(max_iters):
# ----> 8         z = z**2 + c
#       9         diverge = z*conj(z) > 4
#      10         div_now = diverge & (divTime==max_iters)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'

# %%
a = complex(0,1)

# %%
a.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-74befb814698> in <module>()
# ----> 1 a.shape
#
# AttributeError: 'complex' object has no attribute 'shape'
